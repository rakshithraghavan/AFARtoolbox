# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshithraghavan/AFARtoolbox/blob/master/ML_Fest_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Convolution Neural Networks Basics**

# %% [markdown]
# Convolutions Helps Neural Networks in reducing no of parameters as it shares parameters across neurons and acts as a feature detector (e.g vertical/horizontal edge detector).

# %% [markdown]
# ##<h2>Filter
# <h5>A transformation filter is used to learn the shared information in image pixels.

# %% [markdown]
# <img src='data:image/png;base64,...' />

# %% [markdown]
# <img src='data:image/png;base64,...' />

# %% [markdown]
# ##<h2>Stride
# <h5>how many cells filter is moved next in one step.

# %% [markdown]
# <img src='data:image/png;base64,...' />

# %% [markdown]
# ##<h2>Padding
# <h5>how many cells to add to border of image so that output image size remains same.

# %% [markdown]
# <img src='data:image/png;base64,...' />

# %% [markdown]
# ##<h2>Output Shape size</h2>

# %% [markdown]
# <p>
# The formulas relating the output shape of the convolution to the input shape is:
# <p>
# $ n_H = \displaystyle\lfloor \frac{n_{H_{prev}} - f + 2 \times pad}{stride} \rfloor +1 $
# <p>$ n_W = \displaystyle\lfloor \frac{n_{W_{prev}} - f + 2 \times pad}{stride} \rfloor +1 $

# %%
import numpy as np 
import pandas as pd 
import math
import zipfile
import scipy.optimize as op
import matplotlib.pyplot as plt
import cv2 as cv2
import tensorflow as tf

# %%
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##<H2>Read Image

# %%
#Read image in Grayscale
im = cv2.imread('../input/SampleImage.JPG',cv2.IMREAD_GRAYSCALE)
im=cv2.resize(im, (100,100))

# %%
img = files.upload()
# Out:
#      <input type="file" id="files-21fc2f9f-21d6-40ec-94a3-8942f749a061" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21fc2f9f-21d6-40ec-94a3-8942f749a061">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SampleImage.JPG to SampleImage.JPG

# %% [markdown]
# ##<h2> View Image

# %%
plt.axis('off')
im = cv2.imread('/content/SampleImage.JPG', cv2.IMREAD_GRAYSCALE)
im=cv2.resize(im, (100,100))
plt.imshow(im)
plt.show()

# %% [markdown]
# ##<h2> View Image Data

# %%
print('Image Size=',im.shape)
# Out:
# Image Size= (100, 100)

# %% [markdown]
# ##<h2>Padding and Stride

# %%
#Filters
vfilter=np.array([[-1.,0.,1.],[-1.,0.,1.],[-1.,0.,1.]])
hfilter=np.array([[-1.,-1.,-1.],[0.,0.,0.],[1.,1.,1.]])
f=len(vfilter)

#Padding
pad=1
padImg=np.pad(im, ((pad, pad), (pad, pad)), 'constant', constant_values=(0, 0))

#Stride
stride=1

#Out image size calculations
n_H_prev,n_W_prev=im.shape
n_H = int((n_H_prev - f + 2 * pad) / stride + 1)     
n_W = int((n_W_prev - f + 2 * pad) / stride + 1)
outImg=np.zeros((n_W,n_H))


print('out Image Size=',outImg.shape)
# Out:
# out Image Size= (100, 100)

# %% [markdown]
# ##<h2>Apply Filter Vertical/Horizontal Edge Detecter

# %%
filter=hfilter
for i in range(n_H):
    for j in range(n_W):
        outImg[i,j]= np.sum(np.multiply(padImg[i*stride:i*stride+f,j*stride:j*stride+f],filter))
print('Output Image Size=',outImg.shape)
plt.subplot('121') # row, col, position
plt.imshow(outImg)
plt.title('Horizotal Edges')

filter=vfilter
for i in range(n_H):
    for j in range(n_W):
        outImg[i,j]= np.sum(np.multiply(padImg[i*stride:i*stride+f,j*stride:j*stride+f],filter))
print('Output Image Size=',outImg.shape)
plt.subplot('122') # row, col, position
plt.imshow(outImg)
plt.title('Vertical Edges')

plt.show()
# Out:
# Output Image Size= (100, 100)
# Output Image Size= (100, 100)

# %% [markdown]
# ##<h2>Read Color Image

# %%
#Read image in Grayscale
clrImg = cv2.imread('/content/SampleImage.JPG')
clrImg=cv2.resize(clrImg, (100,100))
plt.axis('off')
plt.imshow(clrImg)
plt.show()

# %% [markdown]
# ##<h2>Notation</h2>

# %% [markdown]
# <p>   $X$ will have dimensions $ (m,n_{H}, n_{W} , n_{C})$
# <p> $m$= No of images in dataset
# <p>$n_{H}$= Height(No of pixels vertically) in image
# <p>$n_{W}$= Width(No of pixels vertically) in image
# <p>$n_{C}$= Height(No of Channels RGB) in image

# %% [markdown]
# ##<h2>Converting Image to input X

# %%
X=np.array([clrImg])     # X=np.array([clrImg1,clrImg2,clrImg3,.....so on])
X.shape
# Out:
# (1, 100, 100, 3)

# %% [markdown]
# ##<h1> Pooling

# %% [markdown]
# <img src='data:image/png;base64,...'>

# %% [markdown]
# <img src='data:image/png;base64,...'>

# %% [markdown]
# output shape of the pooling to the input shape is:
# $$ n_H = \lfloor \frac{n_{H_{prev}} - f}{stride} \rfloor +1 $$
# $$ n_W = \lfloor \frac{n_{W_{prev}} - f}{stride} \rfloor +1 $$
# $$ n_C = n_{C_{prev}}$$

# %%
f=10      #Filter size for pooling
stride=3

m,n_H_prev,n_W_prev,n_C_prev=X.shape
n_H = int(1 + (n_H_prev - f) / stride) # 1 + ((100-10)/3) = 1 + 30 = 31
n_W = int(1 + (n_W_prev - f) / stride) # 1 + ((100-10)/3) = 1 + 30 = 31
n_C = n_C_prev
                  
X_Max=np.zeros((m,n_W,n_H,n_C))
X_Avg=np.zeros((m,n_W,n_H,n_C))
print('out Image Size=',X_Max.shape)

for i in range(m):                         # loop over the training examples
    for h in range(n_H):                 # loop on the vertical axis of the output volume
        for w in range(n_W):                 # loop on the horizontal axis of the output volume
            for c in range (n_C):                # loop over the channels of the output volume
                X_Slice=X[i,h*stride:h*stride+f,w*stride:w*stride+f,c]
                X_Max[i,h,w,c]= np.max(X_Slice)
                X_Avg[i,h,w,c]= np.mean(X_Slice)
                

print('Output Image Size=',X_Max.shape)
plt.subplot('121')
plt.imshow((X_Max[0,:,:,:]).astype(int))
plt.title('Max Pooling')

plt.subplot('122')
plt.imshow((X_Avg[0,:,:,:]).astype(int))
plt.title('Avg Pooling')
plt.show()
# Out:
# out Image Size= (1, 31, 31, 3)
# Output Image Size= (1, 31, 31, 3)

# %% [markdown]
# ---

# %% [markdown]
# #**Keras Implemetation of Cifer Dataset**

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %% [markdown]
# Import Dataset

# %%
from keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
print("x_train shape: ", y_train.shape)
x_train.shape
# Out:
# x_train shape:  (50000, 1)
# (50000, 32, 32, 3)

# %%
x_train[0][0][0]
# Out:
# array([59, 62, 63], dtype=uint8)

# %% [markdown]
# Sample Image

# %%
plt.imshow(x_train[11])

# %%
print(y_train<0)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %% [markdown]
# Categorical Classes within the Dataset

# %%
classification = np.array(['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])
print("Image Belongs To : ", classification[y_train[11]])
# Out:
# Image Belongs To :  ['horse']

# %%
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %%
y_train_one_hot.shape
# Out:
# (50000, 10)

# %% [markdown]
# Normalizing data values between 0 to 1

# %%
x_train = x_train/255
x_test = x_test/255

# %% [markdown]
# Preparing Sequential Model

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               204928
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 271,786
# Trainable params: 271,786
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compling Model

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# Training of Model Starts

# %%
hist = model.fit(x_train, y_train_one_hot,
          batch_size=64,
          epochs=10,
          validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 127s 202ms/step - loss: 1.3169 - accuracy: 0.5267 - val_loss: 1.1724 - val_accuracy: 0.5789
# Epoch 2/10
# 625/625 [==============================] - 127s 203ms/step - loss: 1.1158 - accuracy: 0.6039 - val_loss: 0.9853 - val_accuracy: 0.6505
# Epoch 3/10
# 625/625 [==============================] - 127s 203ms/step - loss: 0.9751 - accuracy: 0.6586 - val_loss: 0.8965 - val_accuracy: 0.6870
# Epoch 4/10
# 625/625 [==============================] - 127s 203ms/step - loss: 0.8773 - accuracy: 0.6916 - val_loss: 0.8370 - val_accuracy: 0.7121
# Epoch 5/10
# 625/625 [==============================] - 127s 204ms/step - loss: 0.8098 - accuracy: 0.7149 - val_loss: 0.8407 - val_accuracy: 0.7079
# Epoch 6/10
# 625/625 [==============================] - 127s 203ms/step - loss: 0.7479 - accuracy: 0.7357 - val_loss: 0.7587 - val_accuracy: 0.7335
# Epoch 7/10
# 625/625 [==============================] - 127s 203ms/step - loss: 0.6920 - accuracy: 0.7562 - val_loss: 0.7433 - val_accuracy: 0.7443
# Epoch 8/10
# 625/625 [==============================] - 127s 203ms/step - loss: 0.6549 - accuracy: 0.7685 - val_loss: 0.7269 - val_accuracy: 0.7478
# Epoch 9/10
# 625/625 [==============================] - 127s 203ms/step - loss: 0.6142 - accuracy: 0.7821 - val_loss: 0.7444 - val_accuracy: 0.7426
# Epoch 10/10
# 625/625 [==============================] - 127s 203ms/step - loss: 0.5755 - accuracy: 0.7968 - val_loss: 0.7495 - val_accuracy: 0.7463

# %% [markdown]
# Evaluating the accuracy of Model

# %%
model.evaluate(x_test, y_test_one_hot)[0]
# Out:
# 313/313 [==============================] - 8s 25ms/step - loss: 0.7827 - accuracy: 0.7298
# 0.7826511859893799

# %% [markdown]
# Plotting Train Vs Validation Accuracy Graph

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title("Accuracy")
plt.xlabel('Accuracy')
plt.ylabel('epoch')
plt.legend(['Train', 'Val'])
plt.show()

# %%
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])

# %% [markdown]
# ---

# %% [markdown]
# #**Data Augmentation**

# %% [markdown]
# ![data_aug.png](data:image/png;base64,...)

# %% [markdown]
# 1. Used to increase the amount of data.
# 2. Adds modified copies of existing data.
# 3. Helps to reduce overfitting

# %% [markdown]
# ##Data Augmentation without the use of Keras

# %%
#Translation
import numpy as np
import cv2
import matplotlib.pyplot as plt

path=input("Input path address:")
x=int(input("Enter your x0:"))
y=int(input("Enter your y0:"))

img=cv2.imread(path)
M=np.float32([[1,0,x],[0,1,y]])
shifted=cv2.warpAffine(img,M,(img.shape[1],img.shape[0]))

plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(shifted, cv2.COLOR_RGB2BGR))
# Out:
# Input path address:/content/car.jpg
# Enter your x0:20
# Enter your y0:50

# %%
#Rotation
import numpy as np
import cv2
import matplotlib.pyplot as plt

path=input("Input path address:")
angle=int(input("Enter your angle :"))
reduction=float(input("Enter your reduction factor:"))
img=cv2.imread(path)

(h,w)=img.shape[:2]
center=(w/2,h/2)

M=cv2.getRotationMatrix2D(center,angle,reduction)
rotate=cv2.warpAffine(img,M,(w,h))

plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(rotate, cv2.COLOR_RGB2BGR))
# Out:
# Input path address:/content/car.jpg
# Enter your angle :45
# Enter your reduction factor:0.5

# %%
#Scaling
import numpy as np
import cv2
import matplotlib.pyplot as plt

path=input("Input path address:")
s=float(input("Enter your scaling parameter:"))
img=cv2.imread(path)

print(img.shape)


Width = int(img.shape[1] * s/100 )
Height = int(img.shape[0] * s/100)
dim = (Width, Height)
scale=cv2.resize(img,dim,interpolation=cv2.INTER_AREA)#scaling function


plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(scale, cv2.COLOR_RGB2BGR))
# Out:
# Input path address:/content/car.jpg
# Enter your scaling parameter:50
# (667, 1000, 3)

# %%
#Flippig
import numpy as np
import cv2
import matplotlib.pyplot as plt

path=input("Input path address:")
img=cv2.imread(path)

flipH=cv2.flip(img,1)#flip functions
flipV=cv2.flip(img,0)
flipHV=cv2.flip(img,-1)

plt.subplot(2,2,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
plt.subplot(2,2,2)
plt.imshow(cv2.cvtColor(flipH, cv2.COLOR_RGB2BGR))
plt.subplot(2,2,3)
plt.imshow(cv2.cvtColor(flipV, cv2.COLOR_RGB2BGR))
plt.subplot(2,2,4)
plt.imshow(cv2.cvtColor(flipHV, cv2.COLOR_RGB2BGR))
# Out:
# Input path address:/content/car.jpg

# %%
#Cropping
import numpy as np
import cv2
import matplotlib.pyplot as plt

path=input("Input path address:")
x1=int(input("Enter x1 to be cropped: "))
x2=int(input("Enter x2 to be cropped: "))
y1=int(input("Enter y1 to be cropped: "))
y2=int(input("Enter y2 to be cropped: "))
img=cv2.imread(path)

crop=img[x1:x2,y1:y2]#crop function
plt.imshow(cv2.cvtColor(crop, cv2.COLOR_RGB2BGR))
# Out:
# Input path address:/content/car.jpg
# Enter x1 to be cropped: 2
# Enter x2 to be cropped: 100
# Enter y1 to be cropped: 3
# Enter y2 to be cropped: 200

# %% [markdown]
# ##Data Augmentation using Keras inbuilt function

# %%
# example image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('/content/car.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(width_shift_range=[-200,200])#height_shift_range=0.5,brightness_range=[0.2,1.0],
#rotation_range=90,zoom_range=[0.5,1.0],horizontal_flip=True
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()
